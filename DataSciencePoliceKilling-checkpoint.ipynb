# %% [markdown]
# # Introduction

# %% [markdown]
# Since Jan. 1, 2015, [The Washington Post](https://www.washingtonpost.com/) has been compiling a database of every fatal shooting in the US by a police officer in the line of duty.
#
# <center><img src=https://i.imgur.com/sX3K62b.png></center>
#
# While there are many challenges regarding data collection and reporting, The Washington Post has been tracking more than a dozen details about each killing. This includes the race, age and gender of the deceased, whether the person was armed, and whether the victim was experiencing a mental-health crisis. The Washington Post has gathered this supplemental information from law enforcement websites, local new reports, social media, and by monitoring independent databases such as "Killed by police" and "Fatal Encounters". The Post has also conducted additional reporting in many cases.
#
# There are 4 additional datasets: US census data on poverty rate, high school graduation rate, median household income, and racial demographics. [Source of census data](https://factfinder.census.gov/faces/nav/jsf/pages/community_facts.xhtml).

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab

# %%
# %pip install --upgrade plotly
# Out:
# ...
#      |████████████████████████████████| 13.1MB 310kB/s
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objects as gp
import matplotlib.pyplot as mplt
import seaborn as sns
from collections import Counter

# %% [markdown]
# ## Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Load the Data

# %%
df_hh_income = pd.read_csv('Median_Household_Income_2015.csv', encoding="windows-1252")
df_pct_poverty = pd.read_csv('Pct_People_Below_Poverty_Level.csv', encoding="windows-1252")
df_pct_completed_hs = pd.read_csv('Pct_Over_25_Completed_High_School.csv', encoding="windows-1252")
df_share_race_city = pd.read_csv('Share_of_Race_By_City.csv', encoding="windows-1252")
df_fatalities = pd.read_csv('Deaths_by_Police_US.csv', encoding="windows-1252")

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of the DataFrames?
# * How many rows and columns do they have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_hh_income.shape
# Out:
# (29322, 3)

# %%
df_hh_income.head(5)
# Out:
#   Geographic Area             City Median Income
# 0              AL       Abanda CDP         11207
# 1              AL   Abbeville city         25615
# 2              AL  Adamsville city         42575
# 3              AL     Addison town         37083
# 4              AL       Akron town         21667

# %%
df_hh_income.columns
# Out:
# Index(['Geographic Area', 'City', 'Median Income'], dtype='object')

# %%
df_hh_income
# Out:
#       Geographic Area                    City Median Income
# 0                  AL              Abanda CDP         11207
# 1                  AL          Abbeville city         25615
# 2                  AL         Adamsville city         42575
# 3                  AL            Addison town         37083
# 4                  AL              Akron town         21667
# ...               ...                     ...           ...
# 29317              WY  Woods Landing-Jelm CDP           NaN
# 29318              WY            Worland city         41523
# 29319              WY             Wright town         77114
# 29320              WY              Yoder town         37500
# 29321              WY           Y-O Ranch CDP           NaN
#
# [29322 rows x 3 columns]

# %%
df_pct_poverty
# Out:
#       Geographic Area                    City poverty_rate
# 0                  AL              Abanda CDP         78.8
# 1                  AL          Abbeville city         29.1
# 2                  AL         Adamsville city         25.5
# 3                  AL            Addison town         30.7
# 4                  AL              Akron town           42
# ...               ...                     ...          ...
# 29324              WY  Woods Landing-Jelm CDP         18.6
# 29325              WY            Worland city         15.3
# 29326              WY             Wright town          5.9
# 29327              WY              Yoder town          5.4
# 29328              WY           Y-O Ranch CDP            0
#
# [29329 rows x 3 columns]

# %%
df_pct_poverty.shape
# Out:
# (29329, 3)

# %%
df_pct_poverty.columns
# Out:
# Index(['Geographic Area', 'City', 'poverty_rate'], dtype='object')

# %%
df_pct_poverty.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
df_pct_completed_hs
# Out:
#       Geographic Area                    City percent_completed_hs
# 0                  AL              Abanda CDP                 21.2
# 1                  AL          Abbeville city                 69.1
# 2                  AL         Adamsville city                 78.9
# 3                  AL            Addison town                 81.4
# 4                  AL              Akron town                 68.6
# ...               ...                     ...                  ...
# 29324              WY  Woods Landing-Jelm CDP                  100
# 29325              WY            Worland city                 85.6
# 29326              WY             Wright town                 89.2
# 29327              WY              Yoder town                 79.4
# 29328              WY           Y-O Ranch CDP                  100
#
# [29329 rows x 3 columns]

# %%
df_pct_completed_hs.shape
# Out:
# (29329, 3)

# %%
df_pct_completed_hs.columns
# Out:
# Index(['Geographic Area', 'City', 'percent_completed_hs'], dtype='object')

# %%
df_pct_completed_hs.head()
# Out:
#   Geographic Area             City percent_completed_hs
# 0              AL       Abanda CDP                 21.2
# 1              AL   Abbeville city                 69.1
# 2              AL  Adamsville city                 78.9
# 3              AL     Addison town                 81.4
# 4              AL       Akron town                 68.6

# %%
df_share_race_city.shape
# Out:
# (29268, 7)

# %%
df_share_race_city.columns
# Out:
# Index(['Geographic area', 'City', 'share_white', 'share_black',
#        'share_native_american', 'share_asian', 'share_hispanic'],
#       dtype='object')

# %%
df_share_race_city.head()
# Out:
#   Geographic area             City share_white share_black  \
# 0              AL       Abanda CDP        67.2        30.2
# 1              AL   Abbeville city        54.4        41.4
# 2              AL  Adamsville city        52.3        44.9
# 3              AL     Addison town        99.1         0.1
# 4              AL       Akron town        13.2        86.5
#
#   share_native_american share_asian share_hispanic
# 0                     0           0            1.6
# 1                   0.1           1            3.1
# 2                   0.5         0.3            2.3
# 3                     0         0.1            0.4
# 4                     0           0            0.3

# %%
df_share_race_city
# Out:
#       Geographic area                    City share_white share_black  \
# 0                  AL              Abanda CDP        67.2        30.2
# 1                  AL          Abbeville city        54.4        41.4
# 2                  AL         Adamsville city        52.3        44.9
# 3                  AL            Addison town        99.1         0.1
# 4                  AL              Akron town        13.2        86.5
# ...               ...                     ...         ...         ...
# 29263              WY  Woods Landing-Jelm CDP        95.9           0
# 29264              WY            Worland city        89.9         0.3
# 29265              WY             Wright town        94.5         0.1
# 29266              WY              Yoder town        97.4           0
# 29267              WY           Y-O Ranch CDP        92.8         1.5
#
#       share_native_american share_asian share_hispanic
# 0                         0           0            1.6
# ...

# %%
df_fatalities.shape
# Out:
# (2535, 14)

# %%
df_fatalities.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
df_fatalities.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun 53.00
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
print(f"No of is NaN: \n{df_hh_income.isna().sum()}")
print(f"No of duplicate rows: {df_hh_income.duplicated().sum()}")
# Out:
# No of is NaN:
# Geographic Area     0
# City                0
# Median Income      51
# dtype: int64
# No of duplicate rows: 0

# %%
print(f"No of is NaN: \n{df_pct_poverty.isna().sum()}")
print(f"No of duplicate rows: {df_pct_poverty.duplicated().sum()}")
# Out:
# No of is NaN:
# Geographic Area    0
# City               0
# poverty_rate       0
# dtype: int64
# No of duplicate rows: 0

# %%
print(f"No of is NaN: \n{df_pct_completed_hs.isna().sum()}")
print(f"No of duplicate rows: {df_pct_completed_hs.duplicated().sum()}")
# Out:
# No of is NaN:
# Geographic Area         0
# City                    0
# percent_completed_hs    0
# dtype: int64
# No of duplicate rows: 0

# %%
print(f"No of is NaN: \n{df_share_race_city.isna().sum()}")
print(f"No of duplicate rows: {df_share_race_city.duplicated().sum()}")
# Out:
# No of is NaN:
# Geographic area          0
# City                     0
# share_white              0
# share_black              0
# share_native_american    0
# share_asian              0
# share_hispanic           0
# dtype: int64
# No of duplicate rows: 0

# %%
print(f"No of is NaN: \n{df_fatalities.isna().sum()}")
print(f"No of duplicate rows: {df_fatalities.duplicated().sum()}")
# Out:
# No of is NaN:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64
# No of duplicate rows: 0

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider how to deal with the NaN values. Perhaps substituting 0 is appropriate.

# %%
df_hh_income[df_hh_income["Median Income"].isna() == True].replace(np.nan,0)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\887916729.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_hh_income[df_hh_income["Median Income"].isna() == True].replace(np.nan,0)
#       Geographic Area                    City  Median Income
# 29119              WY              Albany CDP              0
# 29121              WY              Alcova CDP              0
# 29123              WY    Alpine Northeast CDP              0
# 29126              WY      Antelope Hills CDP              0
# 29129              WY           Arlington CDP              0
# 29130              WY   Arrowhead Springs CDP              0
# 29132              WY       Atlantic City CDP              0
# 29133              WY              Auburn CDP              0
# ...

# %%
df_fatalities[df_fatalities["race"].isna()== True].replace(np.nan,0)
df_fatalities[df_fatalities["armed"].isna()== True].replace(np.nan,0)
df_fatalities[df_fatalities["age"].isna()== True].replace(np.nan,0)
df_fatalities[df_fatalities["flee"].isna()== True].replace(np.nan,0)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\1465603305.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_fatalities[df_fatalities["race"].isna()== True].replace(np.nan,0)
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\1465603305.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_fatalities[df_fatalities["armed"].isna()== True].replace(np.nan,0)
# ...

# %% [markdown]
# # Chart the Poverty Rate in each US State
#
# Create a bar chart that ranks the poverty rate from highest to lowest by US state. Which state has the highest poverty rate? Which state has the lowest poverty rate?  Bar Plot

# %%
df_pct_poverty['poverty_rate'] = pd.to_numeric(df_pct_poverty['poverty_rate'], errors='coerce') # error= coerce - any value not able to change to numeric will be put as NaN
df_pct_poverty['poverty_rate'].fillna(0, inplace=True)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\2256269233.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pct_poverty['poverty_rate'].fillna(0, inplace=True)

# %%
df_pct_poverty[["poverty_rate","Geographic Area"]]
# Out:
#        poverty_rate Geographic Area
# 0             78.80              AL
# 1             29.10              AL
# 2             25.50              AL
# 3             30.70              AL
# 4             42.00              AL
# ...             ...             ...
# 29324         18.60              WY
# 29325         15.30              WY
# 29326          5.90              WY
# 29327          5.40              WY
# 29328          0.00              WY
#
# [29329 rows x 2 columns]

# %%
poverty_per_state=df_pct_poverty.groupby("Geographic Area")["poverty_rate"].mean().reset_index() # after groupby reset index should be done for some datasets

# %%
poverty_per_state.sort_values("poverty_rate", ascending=False, inplace=True)

# %%
poverty_per_state
# Out:
#    Geographic Area  poverty_rate
# 25              MS         26.88
# 3               AZ         25.27
# 10              GA         23.66
# 2               AR         22.96
# 32              NM         22.51
# 18              LA         22.29
# 40              SC         22.11
# 49              WV         21.08
# 1               AL         20.61
# 36              OK         20.55
# 17              KY         20.08
# 24              MO         19.93
# 42              TN         19.89
# 27              NC         19.72
# 43              TX         19.50
# 0               AK         18.68
# 13              ID         18.08
# 7               DC         18.00
# 22              MI         17.90
# 9               FL         17.51
# 21              ME         16.89
# 4               CA         16.89
# 37              OR         16.44
# 26              MT         16.42
# 41              SD         15.75
# 15              IN         15.50
# 35              OH         14.83
# ...

# %%
mplt.figure(figsize=(16,9))
mplt.bar(poverty_per_state["Geographic Area"],poverty_per_state["poverty_rate"])
mplt.xlabel("State")
mplt.ylabel("Poverty Rate")
mplt.title("Poverty Rate in US states")
mplt.xticks(rotation=90)
mplt.tight_layout()
mplt.show()

# %%
print(poverty_per_state.iloc[0]["Geographic Area"])
# Out:
# MS

# %%
print(poverty_per_state.iloc[50]["Geographic Area"])
# Out:
# NJ

# %%
print(poverty_per_state["Geographic Area"].iloc[0])
# Out:
# MS

# %% [markdown]
# # Chart the High School Graduation Rate by US State
#
# Show the High School Graduation Rate in ascending order of US States. Which state has the lowest high school graduation rate? Which state has the highest?

# %%
df_pct_completed_hs['percent_completed_hs']= pd.to_numeric(df_pct_completed_hs['percent_completed_hs'],errors= 'coerce')

# %%
df_pct_completed_hs['percent_completed_hs'].fillna(0,inplace=True)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\3854712799.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_pct_completed_hs['percent_completed_hs'].fillna(0,inplace=True)

# %%
graduationrate= df_pct_completed_hs.groupby('Geographic Area')['percent_completed_hs'].mean().reset_index()
graduationrate.sort_values('percent_completed_hs',ascending= True,inplace= True)

# %%
graduationrate
# Out:
#    Geographic Area  percent_completed_hs
# 43              TX                 74.09
# 25              MS                 78.47
# 10              GA                 78.63
# 32              NM                 78.97
# 18              LA                 79.12
# 3               AZ                 79.22
# 2               AR                 79.95
# 0               AK                 80.10
# 1               AL                 80.16
# 40              SC                 80.65
# 4               CA                 80.82
# 42              TN                 81.63
# 49              WV                 82.14
# 17              KY                 82.22
# 36              OK                 82.46
# 24              MO                 82.79
# 27              NC                 83.14
# 50              WY                 83.97
# 13              ID                 84.42
# 45              VA                 84.88
# 9               FL                 85.46
# 41              SD                 86.18
# ...

# %%
graduationrate['Geographic Area'].iloc[0]
# Out:
# 'TX'

# %%
graduationrate['Geographic Area'].iloc[50]
# Out:
# 'MA'

# %%
mplt.figure(figsize=(16,9))
mplt.bar(graduationrate["Geographic Area"],graduationrate["percent_completed_hs"])
mplt.xlabel("State")
mplt.ylabel("Graduation Rate")
mplt.title("Graduation Rate in US states")
mplt.xticks(rotation=90)
mplt.tight_layout()
mplt.show()

# %% [markdown]
# # Visualise the Relationship between Poverty Rates and High School Graduation Rates
#
# #### Create a line chart with two y-axes to show if the rations of poverty and high school graduation move together.

# %%
graduationrate.sort_values("Geographic Area", ascending=True, inplace=True)
poverty_per_state.sort_values("Geographic Area", ascending=True, inplace=True)

# %%
fig, axs = mplt.subplots(figsize=(16,9)) # used for multiple dataset plots

# Y axis of grduation rate is on left and y axis of poverty rate is on the  right

axs.plot(graduationrate['Geographic Area'], graduationrate['percent_completed_hs'], color='b', label='Graduation Rate')
axs.set_xlabel('State', fontsize=14)
axs.set_ylabel('Graduation Rate %', color='b', fontsize=14)

axs2 = axs.twinx() # to create a Secondary Y axis
axs2.plot(poverty_per_state['Geographic Area'], poverty_per_state['poverty_rate'], color='r', label='Poverty Rate')
axs2.set_ylabel('Poverty Rate %', color='r', fontsize=14)

axs2.set_ylim(axs2.get_ylim()[::-1])           # reverse the axis for the poverty rate # get_ylim returns lower and upper bound of the current y axis
# slicing is done to reverse the y axis

mplt.title('Comparison of Graduation Rate and Poverty Rate of every US State', fontsize=20)
axs.legend(loc='upper left')
axs2.legend(loc='upper right')

mplt.tight_layout()

# %% [markdown]
# #### Now use a Seaborn .jointplot() with a Kernel Density Estimate (KDE) and/or scatter plot to visualise the same relationship

# %%
poverty_and_graduation_rates = pd.merge(poverty_per_state, graduationrate, on='Geographic Area', suffixes=('_poverty', '_graduation'))

# %%
poverty_and_graduation_rates
# Out:
#    Geographic Area  poverty_rate  percent_completed_hs
# 0               AK         18.68                 80.10
# 1               AL         20.61                 80.16
# 2               AR         22.96                 79.95
# 3               AZ         25.27                 79.22
# 4               CA         16.89                 80.82
# 5               CO         13.19                 88.93
# 6               CT          9.14                 91.59
# 7               DC         18.00                 89.30
# 8               DE         12.56                 88.52
# 9               FL         17.51                 85.46
# 10              GA         23.66                 78.63
# 11              HI         13.40                 91.67
# 12              IA         12.23                 89.67
# 13              ID         18.08                 84.42
# 14              IL         13.85                 88.29
# 15              IN         15.50                 86.32
# ...

# %%
sns.jointplot(data=poverty_and_graduation_rates,x= 'poverty_rate',y='percent_completed_hs',kind='scatter',height=5)
mplt.xlabel('Average Poverty Rate %')
mplt.ylabel('Average High School Graduation Rate %')
mplt.show()

# %% [markdown]
# #### Seaborn's `.lmplot()` or `.regplot()` to show a linear regression between the poverty ratio and the high school graduation ratio.

# %%
sns.lmplot(data=poverty_and_graduation_rates,x= 'poverty_rate',y='percent_completed_hs',height=5)#powerful with more arguments like huw col and row
mplt.xlabel('Average Poverty Rate %')
mplt.ylabel('Average High School Graduation Rate %')
mplt.title('Linear Regression between Poverty Rate and High School Graduation Rate')
mplt.show()

# %%
sns.regplot(data=poverty_and_graduation_rates,x= 'poverty_rate',y='percent_completed_hs')# lesspowerful function
mplt.xlabel('Average Poverty Rate %')
mplt.ylabel('Average High School Graduation Rate %')
mplt.title('Linear Regression between Poverty Rate and High School Graduation Rate')
mplt.show()

# %% [markdown]
# # Create a Bar Chart with Subsections Showing the Racial Makeup of Each US State
#
# Visualise the share of the white, black, hispanic, asian and native american population in each US State using a bar chart with sub sections.

# %%
df_share_race_city
# Out:
#       Geographic area                    City share_white share_black  \
# 0                  AL              Abanda CDP        67.2        30.2
# 1                  AL          Abbeville city        54.4        41.4
# 2                  AL         Adamsville city        52.3        44.9
# 3                  AL            Addison town        99.1         0.1
# 4                  AL              Akron town        13.2        86.5
# ...               ...                     ...         ...         ...
# 29263              WY  Woods Landing-Jelm CDP        95.9           0
# 29264              WY            Worland city        89.9         0.3
# 29265              WY             Wright town        94.5         0.1
# 29266              WY              Yoder town        97.4           0
# 29267              WY           Y-O Ranch CDP        92.8         1.5
#
#       share_native_american share_asian share_hispanic
# 0                         0           0            1.6
# ...

# %%
df_share_race_city[['share_white','share_black','share_native_american','share_asian','share_hispanic']]= df_share_race_city[['share_white','share_black','share_native_american','share_asian','share_hispanic']].apply(pd.to_numeric,errors='coerce')

# %%
racial_data=df_share_race_city.groupby('Geographic area')[['share_white','share_black','share_native_american','share_asian','share_hispanic']].mean()

# %%
racial_data.head()
# Out:
#                  share_white  share_black  share_native_american  share_asian  \
# Geographic area
# AK                     45.65         0.57                  45.86         1.39
# AL                     72.51        23.32                   0.66         0.48
# AR                     78.45        16.30                   0.76         0.48
# AZ                     59.93         0.95                  28.59         0.73
# CA                     71.87         2.69                   1.72         5.57
#
#                  share_hispanic
# Geographic area
# AK                         2.15
# AL                         2.98
# AR                         4.27
# AZ                        20.14
# CA                        29.65

# %%
# another type of doing the above step is using a dictionary to apply mean from agg method

# %%
racial_data1=df_share_race_city.groupby('Geographic area').agg({'share_white': 'mean', 'share_black': 'mean', 'share_native_american': 'mean', 'share_asian': 'mean', 'share_hispanic': 'mean'})

racial_data1.head()
# Out:
#                  share_white  share_black  share_native_american  share_asian  \
# Geographic area
# AK                     45.65         0.57                  45.86         1.39
# AL                     72.51        23.32                   0.66         0.48
# AR                     78.45        16.30                   0.76         0.48
# AZ                     59.93         0.95                  28.59         0.73
# CA                     71.87         2.69                   1.72         5.57
#
#                  share_hispanic
# Geographic area
# AK                         2.15
# AL                         2.98
# AR                         4.27
# AZ                        20.14
# CA                        29.65

# %%
racial_data1.plot(kind='bar',stacked=True,figsize=(16,9))
mplt.title('Racial Demography by Geographic Area')
mplt.xlabel('Geographic Area')
mplt.ylabel('Mean Share %')
mplt.legend(title='Racial Demography')
mplt.xticks(rotation=45, ha='right')
mplt.tight_layout()
mplt.show()

# %%
racial_data.plot(kind='bar',stacked=True,figsize=(16,9))
mplt.title('Racial Demography by Geographic Area')
mplt.xlabel('Geographic Area')
mplt.ylabel('Mean Share %')
mplt.legend()
mplt.xticks(rotation=45, ha='right')
mplt.tight_layout()
mplt.show()

# %% [markdown]
# # Create Donut Chart by of People Killed by Race
#
# Hint: Use `.value_counts()`

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
killed=df_fatalities['race'].value_counts() # returns unique values in a series
killed
# Out:
# race
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: count, dtype: int64

# %%
df_fatalities.race.unique() # find all unique values in the column
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
mplt.figure(figsize=(16,9))
mplt.pie(killed,labels=killed.index,autopct='%1.1f%%',startangle=200,colors=mplt.cm.tab10.colors)
#centre_circle=mplt.Circle((0,0),0.70,fc='white')
fig=mplt.gcf()
#fig.gca().add_artist(centre_circle)
mplt.title('Distribution of People Killed in different race')
mplt.show()

# %%
mplt.figure(figsize=(16,9))
mplt.pie(killed,labels=killed.index,autopct='%1.1f%%',startangle=200,colors=mplt.cm.tab10.colors)
centre_circle=mplt.Circle((0,0),0.70,fc='white')# donut size defination 0.70 radius of the circle
fig=mplt.gcf()# get current Figure and assign
fig.gca().add_artist(centre_circle) #get current axes and adds the circle
mplt.title('Distribution of People Killed in different race')
mplt.show()

# %%
mplt.figure(figsize=(16,9))
mplt.pie(killed,labels=killed.index,autopct='%1.1f%%',startangle=200,colors=mplt.cm.tab10.colors)
centre_circle=mplt.Circle((0,0),0.2,fc='white')
fig=mplt.gcf()
fig.gca().add_artist(centre_circle)
mplt.title('Distribution of People Killed in different race')
mplt.show()

# %% [markdown]
# # Create a Chart Comparing the Total Number of Deaths of Men and Women
#
# Use `df_fatalities` to illustrate how many more men are killed compared to women.

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
genderkilled=df_fatalities.gender.value_counts()
genderkilled
# Out:
# gender
# M    2428
# F     107
# Name: count, dtype: int64

# %%
mplt.figure(figsize=(6,6))
mplt.bar(genderkilled.index,genderkilled.values) #index and values Remember
mplt.title('Total Number of Deaths by Gender')
mplt.xlabel('Gender')
mplt.ylabel('No of Deaths')
mplt.show()

# %% [markdown]
# # Create a Box Plot Showing the Age and Manner of Death
#
# Break out the data by gender using `df_fatalities`. Is there a difference between men and women in the manner of death?

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
df_fatalities['age']=df_fatalities['age'].replace(np.nan,0)

# %%
df_fatalities.age.isnull().any() # any() checks for the value
# Out:
# False

# %%
ageofdeath = df_fatalities[['age', 'manner_of_death', 'gender']]
ageofdeath.tail()
# Out:
#        age manner_of_death gender
# 2530 31.00            shot      M
# 2531  0.00            shot      M
# 2532 48.00            shot      M
# 2533 28.00            shot      M
# 2534 32.00            shot      M

# %%
mplt.figure(figsize=(12,6))
sns.boxplot(x='age',y='manner_of_death',hue='gender',data=ageofdeath) # hue is another layer of grouping used for splitting 
#the data based on another categorical value
mplt.show()

# %% [markdown]
# # Were People Armed?
#
# In what percentage of police killings were people armed? Create chart that show what kind of weapon (if any) the deceased was carrying. How many of the people killed by police were armed with guns versus unarmed?

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle  0.00
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
df_fatalities.armed.value_counts()
# Out:
# armed
# gun             1398
# knife            373
# vehicle          177
# unarmed          171
# undetermined     117
#                 ...
# hand torch         1
# garden tool        1
# pole               1
# pick-axe           1
# pen                1
# Name: count, Length: 68, dtype: int64

# %%
df_fatalities.armed.unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'vehicle',
#        'shovel', 'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'crossbow',
#        'metal pole', 'Taser', 'metal pipe', 'metal hand tool',
#        'blunt object', 'metal stick', 'sharp object', 'meat cleaver', nan,
#        'carjack', 'chain', "contractor's level", 'unknown weapon',
#        'stapler', 'beer bottle', 'bean-bag gun',
#        'baseball bat and fireplace poker', 'straight edge razor',
#        'gun and knife', 'ax', 'brick', 'baseball bat', 'hand torch',
#        'chain saw', 'garden tool', 'scissors', 'pole', 'pick-axe',
#        'flashlight', 'baton', 'spear', 'pitchfork', 'hatchet and gun',
#        'rock', 'piece of wood', 'bayonet', 'pipe', 'glass shard',
#        'motorcycle', 'metal rake', 'crowbar', 'oar', 'machete and gun',
# ...

# %%
armed = df_fatalities.copy()

# %%
armed.loc[armed['armed']!='unarmed','armed']='armed'

# %%
armed.armed.unique()
# Out:
# array(['armed', 'unarmed'], dtype=object)

# %%
armed_vs_unarmed = armed['armed'].value_counts()
armed_vs_unarmed
# Out:
# armed
# armed      2364
# unarmed     171
# Name: count, dtype: int64

# %%
mplt.figure(figsize=(8, 8))
mplt.title('Police shootings')
mplt.pie(armed_vs_unarmed, labels=armed_vs_unarmed.index, autopct='%1.1f%%', startangle=140, colors=mplt.cm.tab10.colors)
mplt.show()

# %%
arm = df_fatalities.armed.value_counts()
arm
# Out:
# armed
# gun             1398
# knife            373
# vehicle          177
# unarmed          171
# undetermined     117
#                 ...
# hand torch         1
# garden tool        1
# pole               1
# pick-axe           1
# pen                1
# Name: count, Length: 68, dtype: int64

# %%
mplt.figure(figsize=(25,25))
arm.plot(kind='bar'),
mplt.title('Counts of Different Weapons/Means in Fatalities')
mplt.xlabel('Armed')
mplt.ylabel('Count')
mplt.xticks(rotation=90)
mplt.show()

# %% [markdown]
# # How Old Were the People Killed?

# %% [markdown]
# Work out what percentage of people killed were under 25 years old.

# %%
total=df_fatalities.age.count()
total
# Out:
# 2535

# %%
youngage=df_fatalities.loc[df_fatalities['age']<25]
under = youngage.id.count()
under
# Out:
# 527

# %%
overage = df_fatalities.loc[df_fatalities['age'] > 25]
over = overage.id.count()
over
# Out:
# 1905

# %%
print(f"{round((under / (under+over)) * 100)}% of people killed were under 25 years old.")
# Out:
# 22% of people killed were under 25 years old.

# %% [markdown]
# Create a histogram and KDE plot that shows the distribution of ages of the people killed by police.

# %%
mplt.figure(figsize=(16, 9))
mplt.title('Ages of The People Killed by Police')
sns.histplot(data=df_fatalities, x="age", kde=True)
mplt.show()

# %% [markdown]
# Create a seperate KDE plot for each race. Is there a difference between the distributions?

# %%
mplt.figure(figsize=(16, 9))
mplt.title('Ages of The People Killed by Police by Race')
sns.histplot(data=df_fatalities, x="age", kde=True, hue='race') #kernal density estimation
mplt.show()

# %%
mplt.figure(figsize=(16, 9))
mplt.title('Ages of The People Killed by Police by Race')
sns.histplot(data=df_fatalities, x="age", kde=True, hue='race', element='step') #kernal density estimation
mplt.show()

# %%
mplt.figure(figsize=(16, 9))
mplt.title('Ages of The People Killed by Police by Race')
sns.histplot(data=df_fatalities, x="age", kde=True, hue='race', element='poly') #kernal density estimation
mplt.show()

# %% [markdown]
# # Race of People Killed
#
# Create a chart that shows the total number of people killed by race.

# %%
race_killed= df_fatalities.race.value_counts()
race_killed
# Out:
# race
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: count, dtype: int64

# %%
mplt.figure(figsize=(8,8))
mplt.title('race of the people killed')
mplt.pie(race_killed,labels=race_killed.index,autopct='%1.1f%%',startangle=180, colors=mplt.cm.tab10.colors)
mplt.show()

# %% [markdown]
# # Mental Illness and Police Killings
#
# What percentage of people killed by police have been diagnosed with a mental illness?

# %%
signsmental=df_fatalities.signs_of_mental_illness.value_counts()
signsmental
# Out:
# signs_of_mental_illness
# False    1902
# True      633
# Name: count, dtype: int64

# %%
mplt.figure(figsize=(10,10))
mplt.title('Killed by Police that have a mental illness')
mplt.pie(signsmental, labels=signsmental.index, autopct='%1.1f%%', startangle=140, colors=mplt.cm.tab10.colors)
mplt.show()

# %% [markdown]
# # In Which Cities Do the Most Police Killings Take Place?
#
# Create a chart ranking the top 10 cities with the most police killings. Which cities are the most dangerous?

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle  0.00
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
cities=df_fatalities.city.value_counts().head(10)
cities
# Out:
# city
# Los Angeles    39
# Phoenix        31
# Houston        27
# Chicago        25
# Las Vegas      21
# San Antonio    20
# Columbus       19
# Austin         18
# Miami          18
# St. Louis      15
# Name: count, dtype: int64

# %%
mplt.figure(figsize=(16, 9))
mplt.title('The Top 10 Cities With The Most Police Killings', fontsize=16)
mplt.ylabel('Police Killings')
mplt.xlabel('City')
mplt.xticks(rotation=90)
mplt.bar(cities.index, cities, label=cities.index, linewidth=5)
mplt.show()

# %% [markdown]
# # Rate of Death by Race
#
# Find the share of each race in the top 10 cities. Contrast this with the top 10 cities of police killings to work out the rate at which people are killed by race for each city.

# %%
top=df_fatalities[['race','city']]
top
# Out:
#      race           city
# 0       A        Shelton
# 1       W          Aloha
# 2       H        Wichita
# 3       W  San Francisco
# 4       H          Evans
# ...   ...            ...
# 2530  NaN    Kansas City
# 2531  NaN    Albuquerque
# 2532  NaN          Melba
# 2533    B        Oshkosh
# 2534    B       Brooklyn
#
# [2535 rows x 2 columns]

# %%
for c in cities.index: #cities have the top 10 cities with most shootings
    mplt.figure(figsize=(8,8))
    top_cities=top.loc[top['city']==c]
    city=top_cities.race.value_counts()
    mplt.bar(city.index, city, label=c,color='black')
    mplt.legend(loc='best')
    mplt.show()

# %% [markdown]
# # Create a Choropleth Map of Police Killings by US State
#
# Which states are the most dangerous? Compare your map with your previous chart. Are these the same states with high degrees of poverty?

# %%
df_fatalities.state.value_counts()
# Out:
# state
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# IN     43
# WI     43
# KY     43
# NV     42
# OR     38
# MD     38
# MI     37
# NJ     35
# MN     32
# WV     27
# AR     26
# KS     24
# MS     23
# UT     23
# MA     22
# ID     17
# AK     15
# NE     15
# ME     13
# IA     12
# MT     11
# HI     11
# DC     11
# SD     10
# CT      9
# DE      8
# WY      8
# NH      7
# ND      4
# VT      3
# RI      2
# Name: count, dtype: int64

# %%
map=df_fatalities.groupby('state').size().sort_values(ascending=False)
map
# Out:
# state
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# NM     51
# PA     51
# AL     50
# VA     47
# NY     45
# SC     44
# KY     43
# WI     43
# IN     43
# NV     42
# OR     38
# MD     38
# MI     37
# NJ     35
# MN     32
# WV     27
# AR     26
# KS     24
# MS     23
# UT     23
# MA     22
# ID     17
# AK     15
# NE     15
# ME     13
# IA     12
# MT     11
# HI     11
# DC     11
# SD     10
# CT      9
# DE      8
# WY      8
# NH      7
# ND      4
# VT      3
# RI      2
# dtype: int64

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map.index,
    z = map,
    locationmode = 'USA-states',
    colorscale = 'reds',
    colorbar_title = "Police Killings",
))

fig.update_layout(
    title_text = 'Police Killings by US State',
    geo_scope='usa',
)

fig.show()

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map.index,
    z = map, # to color each location the data that is being used
    locationmode = 'USA-states',
    colorscale = 'blackbody',
    colorbar_title = "Police Killings",
))

fig.update_layout(
    title_text = 'Police Killings by US State',
    geo_scope='usa',
)

fig.show()

# %%
fig = go.Figure(data=go.Choropleth(
    locations=map.index,
    z = map, # to color each location the data that is being used
    locationmode = 'USA-states',
    colorscale = 'blackbody',
    colorbar_title = "Police Killings",
))

fig.update_layout(
    title_text='Police Killings by US State',
    geo_scope='north america',
)
fig.show()

# %% [markdown]
# # Number of Police Killings Over Time
#
# Analyse the Number of Police Killings over Time. Is there a trend in the data?

# %%
df_fatalities
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun 53.00
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun 47.00
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed 23.00
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon 32.00
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun 39.00
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun 31.00
# 2531  2813               TK TK  28/07/17              shot     vehicle  0.00
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun 48.00
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle 28.00
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife 32.00
#
# ...

# %%
monthly_data=df_fatalities.copy()

# %%
monthly_data.date=pd.to_datetime(monthly_data.date, infer_datetime_format=True).dt.to_period('M')
monthly_data.date = monthly_data.date.astype(str)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_2440\1202878690.py:1: UserWarning:
#
# The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.

# %%
history=monthly_data.groupby('date').size()
history
# Out:
# date
# 2015-01    70
# 2015-02    78
# 2015-03    87
# 2015-04    88
# 2015-05    85
# 2015-06    68
# 2015-07    85
# 2015-08    86
# 2015-09    90
# 2015-10    89
# 2015-11    80
# 2015-12    85
# 2016-01    85
# 2016-02    79
# 2016-03    89
# 2016-04    75
# 2016-05    82
# 2016-06    90
# 2016-07    78
# 2016-08    79
# 2016-09    71
# 2016-10    77
# 2016-11    84
# 2016-12    74
# 2017-01    75
# 2017-02    69
# 2017-03    74
# 2017-04    70
# 2017-05    61
# 2017-06    63
# 2017-07    71
# 2017-08    18
# 2017-09    23
# 2017-10    21
# 2017-11    16
# 2017-12    20
# dtype: int64

# %%
mplt.figure(figsize=(16, 9))
mplt.plot(history.index, history)
mplt.xticks(ticks=history.index, rotation=45)
mplt.title('Police Killings Over Time')
mplt.xlabel('Month')
mplt.ylabel('Killings')

mplt.show()

# %% [markdown]
# # Epilogue
#
# Now that you have analysed the data yourself, read [The Washington Post's analysis here](https://www.washingtonpost.com/graphics/investigations/police-shootings-database/).
